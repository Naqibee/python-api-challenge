# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import csv

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 570

# %% [markdown]
# ---

# %% [markdown]
#  Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval             ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | ulsteinvik
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | ujae
# Processing Record 5 of Set 1 | mawu
# Processing Record 6 of Set 1 | edinburgh of the seven seas
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | grytviken
# Processing Record 9 of Set 1 | stanley
# Processing Record 10 of Set 1 | banfora
# Processing Record 11 of Set 1 | dudinka
# Processing Record 12 of Set 1 | talnakh
# Processing Record 13 of Set 1 | iqaluit
# Processing Record 14 of Set 1 | puerto natales
# Processing Record 15 of Set 1 | adamstown
# Processing Record 16 of Set 1 | invercargill
# Processing Record 17 of Set 1 | tazovsky
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | waitangi
# Processing Record 20 of Set 1 | papatowai
# Processing Record 21 of Set 1 | kirakira
# Processing Record 22 of Set 1 | margaret river
# Processing Record 23 of Set 1 | kamyshlov
# Processing Record 24 of Set 1 | port lincoln
# Processing Record 25 of Set 1 | wailua homesteads
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | mohr
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | port mathurin
# Processing Record 30 of Set 1 | chonchi
# Processing Record 31 of Set 1 | westport
# Processing Record 32 of Set 1 | vidyayevo
# Processing Record 33 of Set 1 | richards bay
# Processing Record 34 of Set 1 | bilibino
# Processing Record 35 of Set 1 | isafjordur
# Processing Record 36 of Set 1 | moyobamba
# Processing Record 37 of Set 1 | bubaque
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | blackmans bay
# Processing Record 40 of Set 1 | utrik
# Processing Record 41 of Set 1 | mount gambier
# Processing Record 42 of Set 1 | hamilton
# Processing Record 43 of Set 1 | varna
# Processing Record 44 of Set 1 | tiksi
# Processing Record 45 of Set 1 | bodaybo
# Processing Record 46 of Set 1 | lagoa
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | regina
# Processing Record 49 of Set 1 | touros
# Processing Record 50 of Set 1 | cafayate
# Processing Record 0 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 1 of Set 2 | san sebastian de la gomera
# Processing Record 2 of Set 2 | harwich
# Processing Record 3 of Set 2 | petukhovo
# Processing Record 4 of Set 2 | brisas de zicatela
# Processing Record 5 of Set 2 | namibe
# Processing Record 6 of Set 2 | bethel
# Processing Record 7 of Set 2 | atafu village
# Processing Record 8 of Set 2 | thompson
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | anadyr
# Processing Record 11 of Set 2 | udachny
# Processing Record 12 of Set 2 | cobija
# Processing Record 13 of Set 2 | hanko
# Processing Record 14 of Set 2 | ploudalmezeau
# Processing Record 15 of Set 2 | enewetak
# Processing Record 16 of Set 2 | dzhambeyty
# Processing Record 17 of Set 2 | ola
# Processing Record 18 of Set 2 | east london
# Processing Record 19 of Set 2 | howrah
# Processing Record 20 of Set 2 | korla
# Processing Record 21 of Set 2 | san jose del cabo
# Processing Record 22 of Set 2 | saudarkrokur
# Processing Record 23 of Set 2 | iskateley
# Processing Record 24 of Set 2 | alice springs
# Processing Record 25 of Set 2 | hirara
# Processing Record 26 of Set 2 | i-n-salah
# Processing Record 27 of Set 2 | college
# Processing Record 28 of Set 2 | hawaiian paradise park
# Processing Record 29 of Set 2 | ilulissat
# Processing Record 30 of Set 2 | mili
# Processing Record 31 of Set 2 | mossel bay
# Processing Record 32 of Set 2 | bay city
# Processing Record 33 of Set 2 | jamestown
# Processing Record 34 of Set 2 | khashuri
# Processing Record 35 of Set 2 | hammerfest
# Processing Record 36 of Set 2 | sinabang
# Processing Record 37 of Set 2 | avarua
# Processing Record 38 of Set 2 | uturoa
# Processing Record 39 of Set 2 | kirkwall
# Processing Record 40 of Set 2 | karratha
# Processing Record 41 of Set 2 | lemoore
# Processing Record 42 of Set 2 | carora
# Processing Record 43 of Set 2 | kerikeri
# Processing Record 44 of Set 2 | phalaborwa
# Processing Record 45 of Set 2 | west island
# Processing Record 46 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 47 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 48 of Set 2 | ribeira grande
# Processing Record 49 of Set 2 | tura
# Processing Record 0 of Set 3 | siniscola
# Processing Record 1 of Set 3 | prince rupert
# Processing Record 2 of Set 3 | keetmanshoop
# Processing Record 3 of Set 3 | galliano
# Processing Record 4 of Set 3 | hadibu
# Processing Record 5 of Set 3 | baiti
# Processing Record 6 of Set 3 | cargados carajos
# City not found. Skipping...
# Processing Record 7 of Set 3 | ust-nera
# Processing Record 8 of Set 3 | badger
# Processing Record 9 of Set 3 | qaqortoq
# Processing Record 10 of Set 3 | san borja
# Processing Record 11 of Set 3 | nemuro
# Processing Record 12 of Set 3 | fort bragg
# Processing Record 13 of Set 3 | tidjikja
# Processing Record 14 of Set 3 | brookings
# Processing Record 15 of Set 3 | puerto ayora
# Processing Record 16 of Set 3 | olonkinbyen
# Processing Record 17 of Set 3 | nuriootpa
# Processing Record 18 of Set 3 | whitehorse
# Processing Record 19 of Set 3 | hakui
# Processing Record 20 of Set 3 | camocim
# Processing Record 21 of Set 3 | alofi
# Processing Record 22 of Set 3 | san luis
# Processing Record 23 of Set 3 | broken hill
# Processing Record 24 of Set 3 | akureyri
# Processing Record 25 of Set 3 | nar'yan-mar
# Processing Record 26 of Set 3 | xinmin
# Processing Record 27 of Set 3 | salekhard
# Processing Record 28 of Set 3 | bani walid
# Processing Record 29 of Set 3 | daru
# Processing Record 30 of Set 3 | yellowknife
# Processing Record 31 of Set 3 | dwarka
# Processing Record 32 of Set 3 | punta arenas
# Processing Record 33 of Set 3 | ko pha ngan
# Processing Record 34 of Set 3 | kapit
# Processing Record 35 of Set 3 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 36 of Set 3 | ginir
# Processing Record 37 of Set 3 | saldanha
# Processing Record 38 of Set 3 | hailar
# Processing Record 39 of Set 3 | le lavandou
# Processing Record 40 of Set 3 | baker city
# Processing Record 41 of Set 3 | toliara
# Processing Record 42 of Set 3 | saga
# Processing Record 43 of Set 3 | emerald
# Processing Record 44 of Set 3 | selkirk
# Processing Record 45 of Set 3 | tofol
# Processing Record 46 of Set 3 | donggang
# Processing Record 47 of Set 3 | shevchenko
# Processing Record 48 of Set 3 | lebu
# Processing Record 49 of Set 3 | warrenton
# Processing Record 0 of Set 4 | turi
# Processing Record 1 of Set 4 | pozanti
# Processing Record 2 of Set 4 | ust'-uda
# Processing Record 3 of Set 4 | popovaca
# Processing Record 4 of Set 4 | iyidere
# Processing Record 5 of Set 4 | aitape
# Processing Record 6 of Set 4 | anqiu
# Processing Record 7 of Set 4 | cabo san lucas
# Processing Record 8 of Set 4 | shiyan
# Processing Record 9 of Set 4 | kushiro
# Processing Record 10 of Set 4 | linxia chengguanzhen
# Processing Record 11 of Set 4 | quepos
# Processing Record 12 of Set 4 | new norfolk
# Processing Record 13 of Set 4 | horta
# Processing Record 14 of Set 4 | susuman
# Processing Record 15 of Set 4 | sumbe
# Processing Record 16 of Set 4 | happy valley-goose bay
# Processing Record 17 of Set 4 | bikenibeu village
# Processing Record 18 of Set 4 | kelso
# Processing Record 19 of Set 4 | ha'il
# Processing Record 20 of Set 4 | troyan
# Processing Record 21 of Set 4 | beberibe
# Processing Record 22 of Set 4 | constantia
# Processing Record 23 of Set 4 | kulhudhuffushi
# Processing Record 24 of Set 4 | lobito
# Processing Record 25 of Set 4 | alcantara
# Processing Record 26 of Set 4 | bichura
# Processing Record 27 of Set 4 | pontian kechil
# Processing Record 28 of Set 4 | vadso
# Processing Record 29 of Set 4 | saipan
# Processing Record 30 of Set 4 | itoigawa
# Processing Record 31 of Set 4 | ciudad lazaro cardenas
# Processing Record 32 of Set 4 | ijuw
# City not found. Skipping...
# Processing Record 33 of Set 4 | harper
# Processing Record 34 of Set 4 | nikolayevsk-on-amure
# Processing Record 35 of Set 4 | prince albert
# Processing Record 36 of Set 4 | bismarck
# Processing Record 37 of Set 4 | plettenberg bay
# Processing Record 38 of Set 4 | miasskoye
# Processing Record 39 of Set 4 | vorgashor
# Processing Record 40 of Set 4 | ciudad cerralvo
# City not found. Skipping...
# Processing Record 41 of Set 4 | mersing
# Processing Record 42 of Set 4 | faliraki
# Processing Record 43 of Set 4 | prado
# Processing Record 44 of Set 4 | karacasu
# Processing Record 45 of Set 4 | kayangel
# Processing Record 46 of Set 4 | fuglafjordur
# Processing Record 47 of Set 4 | sao felix do xingu
# Processing Record 48 of Set 4 | araioses
# Processing Record 49 of Set 4 | la passe
# Processing Record 0 of Set 5 | bengkulu
# Processing Record 1 of Set 5 | hastings
# Processing Record 2 of Set 5 | hobyo
# Processing Record 3 of Set 5 | marco island
# Processing Record 4 of Set 5 | paris
# Processing Record 5 of Set 5 | mugia
# Processing Record 6 of Set 5 | ghat
# Processing Record 7 of Set 5 | paracuru
# Processing Record 8 of Set 5 | okhotsk
# Processing Record 9 of Set 5 | madaoua
# Processing Record 10 of Set 5 | tolanaro
# Processing Record 11 of Set 5 | jinxiang
# Processing Record 12 of Set 5 | corinto
# Processing Record 13 of Set 5 | lhokseumawe
# Processing Record 14 of Set 5 | oriximina
# Processing Record 15 of Set 5 | oranjemund
# Processing Record 16 of Set 5 | porto novo
# Processing Record 17 of Set 5 | pisco
# Processing Record 18 of Set 5 | reggane
# Processing Record 19 of Set 5 | palikir - national government center
# Processing Record 20 of Set 5 | mejit
# Processing Record 21 of Set 5 | kailua-kona
# Processing Record 22 of Set 5 | harstad
# Processing Record 23 of Set 5 | playas
# Processing Record 24 of Set 5 | nenjiang
# Processing Record 25 of Set 5 | yardimli
# Processing Record 26 of Set 5 | rio grande
# Processing Record 27 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 28 of Set 5 | ananindeua
# Processing Record 29 of Set 5 | tromso
# Processing Record 30 of Set 5 | belabo
# Processing Record 31 of Set 5 | yei
# Processing Record 32 of Set 5 | den burg
# Processing Record 33 of Set 5 | fale old settlement
# Processing Record 34 of Set 5 | nagqu
# Processing Record 35 of Set 5 | puerto aysen
# Processing Record 36 of Set 5 | kuybyshevo
# Processing Record 37 of Set 5 | haiku-pauwela
# Processing Record 38 of Set 5 | halvad
# Processing Record 39 of Set 5 | minas de marcona
# Processing Record 40 of Set 5 | cambria
# Processing Record 41 of Set 5 | williams lake
# Processing Record 42 of Set 5 | florence
# Processing Record 43 of Set 5 | parbatipur
# Processing Record 44 of Set 5 | galveston
# Processing Record 45 of Set 5 | hithadhoo
# Processing Record 46 of Set 5 | acajutla
# Processing Record 47 of Set 5 | prince george
# Processing Record 48 of Set 5 | fraserburgh
# Processing Record 49 of Set 5 | mermoz boabab
# Processing Record 0 of Set 6 | holualoa
# Processing Record 1 of Set 6 | kidal
# Processing Record 2 of Set 6 | sola
# Processing Record 3 of Set 6 | machali
# Processing Record 4 of Set 6 | kabompo
# Processing Record 5 of Set 6 | kapuskasing
# Processing Record 6 of Set 6 | dakhla
# Processing Record 7 of Set 6 | mount isa
# Processing Record 8 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 9 of Set 6 | urangan
# Processing Record 10 of Set 6 | arar
# Processing Record 11 of Set 6 | khairpur
# Processing Record 12 of Set 6 | sambava
# Processing Record 13 of Set 6 | isle of lewis
# City not found. Skipping...
# Processing Record 14 of Set 6 | san patricio
# Processing Record 15 of Set 6 | gornozavodsk
# Processing Record 16 of Set 6 | taltal
# Processing Record 17 of Set 6 | glace bay
# Processing Record 18 of Set 6 | mpanda
# Processing Record 19 of Set 6 | santiago
# Processing Record 20 of Set 6 | ungsang-nodongjagu
# Processing Record 21 of Set 6 | conduaga
# Processing Record 22 of Set 6 | north bend
# Processing Record 23 of Set 6 | klyuchi
# Processing Record 24 of Set 6 | palmer
# Processing Record 25 of Set 6 | kununurra
# Processing Record 26 of Set 6 | vila franca do campo
# Processing Record 27 of Set 6 | ashland
# Processing Record 28 of Set 6 | piti village
# Processing Record 29 of Set 6 | shubarshi
# Processing Record 30 of Set 6 | baikonur
# Processing Record 31 of Set 6 | chibougamau
# Processing Record 32 of Set 6 | lakatoro
# Processing Record 33 of Set 6 | qarazhal
# Processing Record 34 of Set 6 | abalak
# Processing Record 35 of Set 6 | lorengau
# Processing Record 36 of Set 6 | imbert
# Processing Record 37 of Set 6 | houghton
# Processing Record 38 of Set 6 | araguaina
# Processing Record 39 of Set 6 | cuito
# Processing Record 40 of Set 6 | svetlyy
# Processing Record 41 of Set 6 | aginskoye
# Processing Record 42 of Set 6 | scarborough
# Processing Record 43 of Set 6 | yonan-up
# Processing Record 44 of Set 6 | sheringham
# Processing Record 45 of Set 6 | puerto san jose
# Processing Record 46 of Set 6 | sandnessjoen
# Processing Record 47 of Set 6 | gadzhiyevo
# Processing Record 48 of Set 6 | gusinoozyorsk
# Processing Record 49 of Set 6 | myeik
# Processing Record 0 of Set 7 | kharkhorin
# Processing Record 1 of Set 7 | eureka
# Processing Record 2 of Set 7 | strezhevoy
# Processing Record 3 of Set 7 | suva
# Processing Record 4 of Set 7 | lockwood
# Processing Record 5 of Set 7 | weno
# Processing Record 6 of Set 7 | matoury
# Processing Record 7 of Set 7 | boyolangu
# Processing Record 8 of Set 7 | aioun
# Processing Record 9 of Set 7 | illapel
# Processing Record 10 of Set 7 | pangoa
# Processing Record 11 of Set 7 | guiren
# Processing Record 12 of Set 7 | mutum biyu
# Processing Record 13 of Set 7 | argo
# Processing Record 14 of Set 7 | afaahiti
# Processing Record 15 of Set 7 | pangody
# Processing Record 16 of Set 7 | malanje
# Processing Record 17 of Set 7 | lihue
# Processing Record 18 of Set 7 | newman
# Processing Record 19 of Set 7 | igarka
# Processing Record 20 of Set 7 | wangqing
# Processing Record 21 of Set 7 | lompoc
# Processing Record 22 of Set 7 | vrangel'
# Processing Record 23 of Set 7 | cherrapunji
# Processing Record 24 of Set 7 | saint-philippe
# Processing Record 25 of Set 7 | carbonear
# Processing Record 26 of Set 7 | ponta delgada
# Processing Record 27 of Set 7 | ahfir
# Processing Record 28 of Set 7 | ban nong wua so
# Processing Record 29 of Set 7 | plastun
# Processing Record 30 of Set 7 | gueltat zemmour
# City not found. Skipping...
# Processing Record 31 of Set 7 | dakoro
# Processing Record 32 of Set 7 | lautoka
# Processing Record 33 of Set 7 | churachandpur
# Processing Record 34 of Set 7 | sao joao dos inhamuns
# Processing Record 35 of Set 7 | malango
# Processing Record 36 of Set 7 | ta`u
# Processing Record 37 of Set 7 | castillos
# Processing Record 38 of Set 7 | thinadhoo
# Processing Record 39 of Set 7 | yanam
# Processing Record 40 of Set 7 | ventspils
# Processing Record 41 of Set 7 | cidreira
# Processing Record 42 of Set 7 | kawthoung
# City not found. Skipping...
# Processing Record 43 of Set 7 | sitia
# Processing Record 44 of Set 7 | egilsstadir
# Processing Record 45 of Set 7 | saint-joseph
# Processing Record 46 of Set 7 | marakkanam
# Processing Record 47 of Set 7 | ovalle
# Processing Record 48 of Set 7 | greymouth
# Processing Record 49 of Set 7 | norrkoping
# Processing Record 0 of Set 8 | safonovo
# Processing Record 1 of Set 8 | greenville
# Processing Record 2 of Set 8 | pandan
# Processing Record 3 of Set 8 | vorkuta
# Processing Record 4 of Set 8 | wanning
# Processing Record 5 of Set 8 | wustermark
# Processing Record 6 of Set 8 | antofagasta
# Processing Record 7 of Set 8 | coahuayana de hidalgo
# Processing Record 8 of Set 8 | fehmarn
# Processing Record 9 of Set 8 | smach mean chey
# City not found. Skipping...
# Processing Record 10 of Set 8 | griffith
# Processing Record 11 of Set 8 | mersa matruh
# Processing Record 12 of Set 8 | waingapu
# Processing Record 13 of Set 8 | turkmenbasy
# Processing Record 14 of Set 8 | colonia
# Processing Record 15 of Set 8 | woodmoor
# Processing Record 16 of Set 8 | portland
# Processing Record 17 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 18 of Set 8 | nuuk
# Processing Record 19 of Set 8 | klaksvik
# Processing Record 20 of Set 8 | oroqen zizhiqi
# Processing Record 21 of Set 8 | moultonborough
# Processing Record 22 of Set 8 | yashkul'
# Processing Record 23 of Set 8 | page
# Processing Record 24 of Set 8 | yylanly
# City not found. Skipping...
# Processing Record 25 of Set 8 | aweil
# Processing Record 26 of Set 8 | tongchuanshi
# Processing Record 27 of Set 8 | caleta de carquin
# Processing Record 28 of Set 8 | labrador city
# Processing Record 29 of Set 8 | paradera
# City not found. Skipping...
# Processing Record 30 of Set 8 | novovolyns'k
# Processing Record 31 of Set 8 | batticaloa
# Processing Record 32 of Set 8 | knokke-heist
# Processing Record 33 of Set 8 | waris aliganj
# Processing Record 34 of Set 8 | takamaka
# City not found. Skipping...
# Processing Record 35 of Set 8 | vilyuchinsk
# Processing Record 36 of Set 8 | rikaze
# Processing Record 37 of Set 8 | demre
# Processing Record 38 of Set 8 | karkira
# Processing Record 39 of Set 8 | ugbokpo
# Processing Record 40 of Set 8 | khandyga
# Processing Record 41 of Set 8 | banyo
# Processing Record 42 of Set 8 | flin flon
# Processing Record 43 of Set 8 | xuddur
# Processing Record 44 of Set 8 | tabuk
# Processing Record 45 of Set 8 | port hedland
# Processing Record 46 of Set 8 | salalah
# Processing Record 47 of Set 8 | ternate
# Processing Record 48 of Set 8 | grand baie
# Processing Record 49 of Set 8 | olinda
# Processing Record 0 of Set 9 | katihar
# Processing Record 1 of Set 9 | gizo
# Processing Record 2 of Set 9 | san sebastian
# Processing Record 3 of Set 9 | jaen
# Processing Record 4 of Set 9 | acapulco de juarez
# Processing Record 5 of Set 9 | kudahuvadhoo
# Processing Record 6 of Set 9 | kamyaran
# Processing Record 7 of Set 9 | kalmunai
# Processing Record 8 of Set 9 | cockburn town
# Processing Record 9 of Set 9 | puerto baquerizo moreno
# Processing Record 10 of Set 9 | banda aceh
# Processing Record 11 of Set 9 | dongola
# Processing Record 12 of Set 9 | uttaradit
# Processing Record 13 of Set 9 | taveta
# Processing Record 14 of Set 9 | los frentones
# Processing Record 15 of Set 9 | chiredzi
# Processing Record 16 of Set 9 | caiaponia
# Processing Record 17 of Set 9 | jinghong
# Processing Record 18 of Set 9 | polyarnyy
# Processing Record 19 of Set 9 | tulum
# Processing Record 20 of Set 9 | puerto santa
# Processing Record 21 of Set 9 | papao
# Processing Record 22 of Set 9 | taoudenni
# Processing Record 23 of Set 9 | west bay
# Processing Record 24 of Set 9 | aykol
# City not found. Skipping...
# Processing Record 25 of Set 9 | queenstown
# Processing Record 26 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 9 | greenland
# Processing Record 28 of Set 9 | preobrazheniye
# Processing Record 29 of Set 9 | mount pearl
# Processing Record 30 of Set 9 | timbuktu
# Processing Record 31 of Set 9 | maun
# Processing Record 32 of Set 9 | long xuyen
# Processing Record 33 of Set 9 | gazojak
# Processing Record 34 of Set 9 | saint lucia
# Processing Record 35 of Set 9 | port alfred
# Processing Record 36 of Set 9 | antsiranana
# Processing Record 37 of Set 9 | kapa'a
# Processing Record 38 of Set 9 | sitka
# Processing Record 39 of Set 9 | mozarlandia
# Processing Record 40 of Set 9 | tvoroyri
# Processing Record 41 of Set 9 | nassau
# Processing Record 42 of Set 9 | carnarvon
# Processing Record 43 of Set 9 | howard springs
# Processing Record 44 of Set 9 | kataragama
# City not found. Skipping...
# Processing Record 45 of Set 9 | sao joao da barra
# Processing Record 46 of Set 9 | dzilam gonzalez
# Processing Record 47 of Set 9 | nur-sultan
# Processing Record 48 of Set 9 | crane
# Processing Record 49 of Set 9 | isla mujeres
# Processing Record 0 of Set 10 | mandalgovi
# Processing Record 1 of Set 10 | liberal
# Processing Record 2 of Set 10 | meckenbeuren
# Processing Record 3 of Set 10 | kyren
# Processing Record 4 of Set 10 | konarka
# Processing Record 5 of Set 10 | zhanibek
# Processing Record 6 of Set 10 | l'alcora
# Processing Record 7 of Set 10 | isangel
# Processing Record 8 of Set 10 | bamboo flat
# Processing Record 9 of Set 10 | victoria point
# Processing Record 10 of Set 10 | kalat
# Processing Record 11 of Set 10 | arraial do cabo
# Processing Record 12 of Set 10 | piacabucu
# Processing Record 13 of Set 10 | usogorsk
# Processing Record 14 of Set 10 | rongelap
# Processing Record 15 of Set 10 | lembar
# City not found. Skipping...
# Processing Record 16 of Set 10 | tsiombe
# Processing Record 17 of Set 10 | flying fish cove
# Processing Record 18 of Set 10 | ploneour-lanvern
# Processing Record 19 of Set 10 | porbandar
# Processing Record 20 of Set 10 | tenenkou
# Processing Record 21 of Set 10 | viedma
# Processing Record 22 of Set 10 | traverse city
# Processing Record 23 of Set 10 | san antonio de pale
# Processing Record 24 of Set 10 | severo-yeniseyskiy
# Processing Record 25 of Set 10 | antonio enes
# Processing Record 26 of Set 10 | st. paul
# Processing Record 27 of Set 10 | erenhot
# Processing Record 28 of Set 10 | poso
# Processing Record 29 of Set 10 | talcahuano
# Processing Record 30 of Set 10 | sint michiel liber
# Processing Record 31 of Set 10 | jinchang
# Processing Record 32 of Set 10 | kotlas
# Processing Record 33 of Set 10 | krasnotur'insk
# Processing Record 34 of Set 10 | xinhui
# Processing Record 35 of Set 10 | bolama
# Processing Record 36 of Set 10 | bel ombre
# Processing Record 37 of Set 10 | odessa
# Processing Record 38 of Set 10 | naze
# Processing Record 39 of Set 10 | agapovka
# Processing Record 40 of Set 10 | hafar al-batin
# Processing Record 41 of Set 10 | mairang
# Processing Record 42 of Set 10 | aldama
# Processing Record 43 of Set 10 | inhambane
# Processing Record 44 of Set 10 | ryotsu-minato
# Processing Record 45 of Set 10 | pingyin
# Processing Record 46 of Set 10 | panama city beach
# Processing Record 47 of Set 10 | dokkum
# Processing Record 48 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 49 of Set 10 | kayar
# Processing Record 0 of Set 11 | donskoye
# Processing Record 1 of Set 11 | zapala
# Processing Record 2 of Set 11 | guatrache
# Processing Record 3 of Set 11 | robore
# Processing Record 4 of Set 11 | tabou
# Processing Record 5 of Set 11 | remire-montjoly
# Processing Record 6 of Set 11 | acigol
# City not found. Skipping...
# Processing Record 7 of Set 11 | praia da vitoria
# Processing Record 8 of Set 11 | grasse
# Processing Record 9 of Set 11 | kirensk
# Processing Record 10 of Set 11 | nejo
# Processing Record 11 of Set 11 | sylvan lake
# Processing Record 12 of Set 11 | bembereke
# Processing Record 13 of Set 11 | masterton
# Processing Record 14 of Set 11 | twon-brass
# Processing Record 15 of Set 11 | morondava
# Processing Record 16 of Set 11 | iwaki
# Processing Record 17 of Set 11 | garcia
# Processing Record 18 of Set 11 | montevideo
# Processing Record 19 of Set 11 | bukittinggi
# Processing Record 20 of Set 11 | watsa
# Processing Record 21 of Set 11 | walvis bay
# Processing Record 22 of Set 11 | las palmas
# Processing Record 23 of Set 11 | salida
# Processing Record 24 of Set 11 | nogliki
# Processing Record 25 of Set 11 | oualidia
# City not found. Skipping...
# Processing Record 26 of Set 11 | logansport
# Processing Record 27 of Set 11 | firuzabad
# Processing Record 28 of Set 11 | chimore
# Processing Record 29 of Set 11 | amursk
# Processing Record 30 of Set 11 | tullamore
# Processing Record 31 of Set 11 | arteche
# Processing Record 32 of Set 11 | bahia de kino
# Processing Record 33 of Set 11 | thief river falls
# Processing Record 34 of Set 11 | keflavik
# Processing Record 35 of Set 11 | katabu
# Processing Record 36 of Set 11 | pokaran
# Processing Record 37 of Set 11 | metlili chaamba
# Processing Record 38 of Set 11 | bocanda
# Processing Record 39 of Set 11 | mutuali
# Processing Record 40 of Set 11 | tahoua
# Processing Record 41 of Set 11 | omidiyeh
# Processing Record 42 of Set 11 | pura
# Processing Record 43 of Set 11 | ashmun
# Processing Record 44 of Set 11 | umarkot
# Processing Record 45 of Set 11 | aykhal
# Processing Record 46 of Set 11 | inga
# Processing Record 47 of Set 11 | sao lourenco do sul
# Processing Record 48 of Set 11 | kashima
# Processing Record 49 of Set 11 | buta
# Processing Record 0 of Set 12 | boende
# Processing Record 1 of Set 12 | dingli
# Processing Record 2 of Set 12 | kuanda
# Processing Record 3 of Set 12 | coyhaique
# Processing Record 4 of Set 12 | el granada
# Processing Record 5 of Set 12 | vihari
# Processing Record 6 of Set 12 | yemetsk
# Processing Record 7 of Set 12 | clinton
# Processing Record 8 of Set 12 | ribeira brava
# Processing Record 9 of Set 12 | mochudi
# Processing Record 10 of Set 12 | ostersund
# Processing Record 11 of Set 12 | mamuju
# Processing Record 12 of Set 12 | nizhnesortymskiy
# Processing Record 13 of Set 12 | n'diareme limamoulaye
# City not found. Skipping...
# Processing Record 14 of Set 12 | talakan
# Processing Record 15 of Set 12 | bowen
# Processing Record 16 of Set 12 | geraldton
# Processing Record 17 of Set 12 | cabedelo
# Processing Record 18 of Set 12 | zaragoza
# Processing Record 19 of Set 12 | taree
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          546
# Lat           546
# Lng           546
# Max Temp      546
# Humidity      546
# Cloudiness    546
# Wind Speed    546
# Country       546
# Date          546
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167      7.04        87          70
# 1         ulsteinvik  62.3432    5.8487      7.50        82         100
# 2       longyearbyen  78.2186   15.6401    -13.09        85          40
# 3               ujae   8.9322  165.7642     26.86        72          99
# 4               mawu  29.5923  107.3139     11.86        72          10
#
#    Wind Speed Country        Date
# 0       15.40      TF  1707755421
# 1        1.34      NO  1707755421
# 2        2.06      SJ  1707755422
# 3        9.65      MH  1707755422
# 4        1.21      CN  1707755423

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data\cities.csv", index_label="City_ID")

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      7.04        87          70
# 1               ulsteinvik  62.3432    5.8487      7.50        82         100
# 2             longyearbyen  78.2186   15.6401    -13.09        85          40
# 3                     ujae   8.9322  165.7642     26.86        72          99
# 4                     mawu  29.5923  107.3139     11.86        72          10
#
#          Wind Speed Country        Date
# City_ID
# 0             15.40      TF  1707755421
# 1              1.34      NO  1707755421
# 2              2.06      SJ  1707755422
# 3              9.65      MH  1707755422
# 4              1.21      CN  1707755423

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolors="black")

# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude vs. Max Temperature (2022-10-18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2022-10-18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolors="black")
# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2022-10-18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolors="black")
# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (2022-10-18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression_plot(x, y, xlabel='', ylabel='', title=''):
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.text(0.5, 0.9, line_eq, fontsize=12, ha='center', transform=plt.gca().transAxes, color='red')

    regress_values = x * slope + intercept
    
    # Plot scatter plot
    plt.scatter(x, y)

    # Plot regression line
    plt.plot(x, slope*x + intercept, color='red')

    # Add labels and title
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    
    # print the r value
    print(f'The r-value is: {r_value**2}')
    
    # Show plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]
# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          ulsteinvik  62.3432    5.8487      7.50        82         100
# 2        longyearbyen  78.2186   15.6401    -13.09        85          40
# 3                ujae   8.9322  165.7642     26.86        72          99
# 4                mawu  29.5923  107.3139     11.86        72          10
# 8             stanley  54.8680   -1.6985      6.77        72          40
#
#          Wind Speed Country        Date
# City_ID
# 1              1.34      NO  1707755421
# 2              2.06      SJ  1707755422
# 3              9.65      MH  1707755422
# 4              1.21      CN  1707755423
# 8              4.63      GB  1707755425

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 0                  port-aux-francais -49.3500  70.2167      7.04        87
# 5        edinburgh of the seven seas -37.0676 -12.3116     17.31        71
# 6                            ushuaia -54.8000 -68.3000     10.81        62
# 7                          grytviken -54.2811 -36.5092      3.73        94
# 13                    puerto natales -51.7236 -72.4875     15.25        44
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                70       15.40      TF  1707755421
# 5                87        7.85      SH  1707755423
# 6                75        7.72      AR  1707755233
# 7                94        1.36      GS  1707755424
# 13               75       10.29      CL  1707755428

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
#linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], 'Latitude', 'Max Temp')
# Scatter plot for latitude vs. maximum temperature in the Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], alpha=0.5, edgecolors='black')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])

# Plot the regression line
plt.plot(northern_hemi_df['Lat'], intercept + slope * northern_hemi_df['Lat'], 'r', label='fitted line')

# Add the equation of the line to the plot
plt.text(0, northern_hemi_df['Max Temp'].max(), f'y = {slope:.2f}x + {intercept:.2f}', color='red')

plt.grid(True)
plt.title("Northern Hemisphere Max Latitude vs. Temperature")
plt.tight_layout()
plt.legend()

# Print the r-value
print(f'The r-value is: {r_value**2}')

# Show plot
plt.show()
# Out:
# The r-value is: 0.7512319133635237

# %%
# Linear regression on Southern Hemisphere
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], 'Latitude', 'Max Temp')
# Out:
# The r-value is: 0.33579321545267177

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], 'Latitude', 'Humidity')
# Out:
# The r-value is: 0.24966429919410502

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], 'Latitude', 'Humidity')
# Out:
# The r-value is: 0.07171462452434872

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], 'Latitude', 'Cloudiness')
# Out:
# The r-value is: 0.040533155816922066

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], 'Latitude', 'Cloudiness')
# Out:
# The r-value is: 0.10153762849513454

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed')
# Out:
# The r-value is: 0.012640786919564394

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed')
# Out:
# The r-value is: 0.012763225017493593

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
